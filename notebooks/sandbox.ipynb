# %%
import yaml
import numpy as np
import pandas as ps
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from pathlib import Path

import matplotlib.pyplot as plt
from skimage.io import imshow

from albumentations.core.serialization import from_dict
from catalyst.dl.runner import SupervisedRunner
import catalyst.dl.callbacks as cbks

from dataset import SteelDataset
from models import UNetResNet
from metrics import MulticlassDiceMetricCallback
from losses import MulticlassDiceLoss

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
config_file = Path('.') / 'configs' / 'simple_unet.yaml'

with open(config_file, 'r') as fuck:
    config = yaml.safe_load(fuck)

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
DATA_FOLDER = Path('..') / 'data'
RANDOM_STATE = np.random.RandomState(seed=2019)
NUM_WORKERS = 12
BATCH_SIZE = 16
NUM_CLASSES = 4
validation_pcnt = 0.1

# %%
def load_transforms(transforms_dict: dict):
    if transforms_dict is not None:
        return from_dict(transforms_dict)
    return None


train_transforms = load_transforms(config['train']['transformations']['train'])
validation_transforms = load_transforms(config['train']['transformations']['validation'])

# %%
train_df = ps.read_csv(config['train']['file'])
train_images_folder = config['train']['folder']

print(f'train images folder - {train_images_folder}')
train_df.head()
# Out:
# train images folder - /home/dmdr/Documents/Code/Python/kaggle/severstal_steel_defect_detection/data/train_images
#    ImageId_ClassId                                      EncodedPixels
# 0  0002cc93b.jpg_1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0002cc93b.jpg_2                                                NaN
# 2  0002cc93b.jpg_3                                                NaN
# 3  0002cc93b.jpg_4                                                NaN
# 4  00031f466.jpg_1                                                NaN

# %%
train_df = train_df[train_df['EncodedPixels'].notnull()].reset_index(drop=True)
train_df['Image'] = train_df['ImageId_ClassId'].apply(lambda img_cls: img_cls.rsplit('_', 1)[0])
train_df['ClassId'] = train_df['ImageId_ClassId'].apply(lambda img_cls: int(img_cls.rsplit('_', 1)[1]) - 1)
train_df = train_df.sort_values(['Image', 'ClassId'])
# train_df = train_df.drop(columns=['ImageId_ClassId'])

print(train_df.dtypes)

train_df.head()
# Out:
# ImageId_ClassId    object
# EncodedPixels      object
# Image              object
# ClassId             int64
# dtype: object
#    ImageId_ClassId                                      EncodedPixels  \
# 0  0002cc93b.jpg_1  29102 12 29346 24 29602 24 29858 24 30114 24 3...
# 1  0007a71bf.jpg_3  18661 28 18863 82 19091 110 19347 110 19603 11...
# 2  000a4bcdd.jpg_1  37607 3 37858 8 38108 14 38359 20 38610 25 388...
# 3  000f6bf48.jpg_4  131973 1 132228 4 132483 6 132738 8 132993 11 ...
# 4  0014fce06.jpg_3  229501 11 229741 33 229981 55 230221 77 230468...
#
#            Image  ClassId
# 0  0002cc93b.jpg        0
# 1  0007a71bf.jpg        2
# 2  000a4bcdd.jpg        0
# 3  000f6bf48.jpg        3
# 4  0014fce06.jpg        2

# %%
train_df['ClassId'].value_counts()
# Out:
# 2    5150
# 0     897
# 3     801
# 1     247
# Name: ClassId, dtype: int64

# %%
def combine_masks(df):
    masks = [[]] * 4
    for idx in df.index:
        masks[df.at[idx, 'ClassId']] = np.array(list(map(int, df.at[idx, 'EncodedPixels'].split())))
    return ps.Series([masks], ['RLEs'])
    

train_set = train_df.groupby('Image').apply(combine_masks).reset_index()

for cls_idx in range(4):
    cls_name = f'IsPresent{cls_idx}'
    train_set[cls_name] = False
    for idx in train_set.index:
        train_set.at[idx, cls_name] = len(train_set.at[idx, 'RLEs'][cls_idx]) > 0


print(train_set.shape)
train_set.head()
# Out:
# (6666, 6)
#            Image                                               RLEs  \
# 0  0002cc93b.jpg  [[29102, 12, 29346, 24, 29602, 24, 29858, 24, ...
# 1  0007a71bf.jpg  [[], [], [18661, 28, 18863, 82, 19091, 110, 19...
# 2  000a4bcdd.jpg  [[37607, 3, 37858, 8, 38108, 14, 38359, 20, 38...
# 3  000f6bf48.jpg  [[], [], [], [131973, 1, 132228, 4, 132483, 6,...
# 4  0014fce06.jpg  [[], [], [229501, 11, 229741, 33, 229981, 55, ...
#
#    IsPresent0  IsPresent1  IsPresent2  IsPresent3
# 0        True       False       False       False
# 1       False       False        True       False
# 2        True       False       False       False
# 3       False       False       False        True
# 4       False       False        True       False

# %%
validation_set = train_set.sample(int(train_set.shape[0] * validation_pcnt),
                                  random_state=RANDOM_STATE)
print(validation_set.shape)
validation_set.head()
# Out:
# (666, 6)
#               Image                                               RLEs  \
# 5524  d2c14891a.jpg  [[], [], [285887, 24, 286117, 51, 286367, 59, ...
# 2292  5a3db6845.jpg  [[], [], [172782, 19, 173002, 55, 173221, 92, ...
# 3179  7a5fae002.jpg  [[], [], [275937, 32, 276129, 96, 276321, 160,...
# 600   17c821b3f.jpg  [[131870, 32, 132097, 66, 132353, 71, 132609, ...
# 2076  5132041da.jpg  [[], [], [366032, 12, 366286, 15, 366539, 18, ...
#
#       IsPresent0  IsPresent1  IsPresent2  IsPresent3
# 5524       False       False        True       False
# 2292       False       False        True       False
# 3179       False       False        True       False
# 600         True       False       False       False
# 2076       False       False        True       False

# %%
def get_loaders() -> dict:
    train_dataset = SteelDataset(
        images=train_set['Image'].values, 
        rles=train_set['RLEs'].values,
        folder=DATA_FOLDER / 'train_images',
        transforms=train_transforms
    )
    validation_dataset = SteelDataset(
        images=validation_set['Image'].values, 
        rles=validation_set['RLEs'].values,
        folder=DATA_FOLDER / 'train_images',
        transforms=validation_transforms
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=BATCH_SIZE,
        shuffle=True,
        num_workers=NUM_WORKERS
    )

    validation_loader = DataLoader(
        validation_dataset,
        batch_size=BATCH_SIZE,
        shuffle=False,
        num_workers=NUM_WORKERS
    )
    
    print(f'Number of batches in train - {len(train_loader)}, '
          f'Number of batches in validation - {len(validation_loader)}')
    
    return {'train': train_loader, 'valid': validation_loader}

# %%
from catalyst.contrib.models.segmentation import Unet

model = Unet(num_classes=5, in_channels=1, num_channels=64, num_blocks=4).to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=5, factor=0.2, verbose=True)

multiclass_dice_loss = MulticlassDiceLoss([1, 2, 3, 4], from_logits=True, weight=None, reduction='elementwise_mean')
cce_loss = CCE(ignore_index=5)
alpha = 0.7
joint_loss = JointLoss(cce_loss, multiclass_dice_loss, alpha, 1 - alpha)

loaders = get_loaders()
# Out:
# Number of batches in train - 417, Number of batches in validation - 42

# %%
runner = SupervisedRunner(device=DEVICE)
runner.train(
    model=model,
    criterion=loss_function,
    optimizer=optimizer,
    loaders=loaders,
    logdir='logs',
    callbacks=[
        MulticlassDiceMetricCallback(class_names=['0', '1', '2', '3', '4']),
        cbks.CheckpointCallback(save_n_best=3),
#         cbks.EarlyStoppingCallback(5, metric='dice')
    ],
    scheduler=scheduler,
    verbose=True,
    minimize_metric=False,
    num_epochs=50
)
# Out:
# 0/50 * Epoch (train): 100% 417/417 [03:50<00:00,  2.20s/it, 0=1.000, 1=0.000, 2=0.001, 3=0.414, 4=0.063, _timers/_fps=5.985, loss=0.542]
# 0/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.68it/s, 0=1.000, 1=0.008, 2=0.000, 3=0.366, 4=0.000, _timers/_fps=3680.425, loss=0.332]
# [2019-08-11 01:26:18,072]
# 0/50 * Epoch 0 (train): 0=0.8343 | 1=0.0763 | 2=0.0005 | 3=0.4315 | 4=0.1542 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=47.6921 | _timers/batch_time=0.3594 | _timers/data_time=0.3449 | _timers/model_time=0.0145 | loss=0.5361
# 0/50 * Epoch 0 (valid): 0=1.0000 | 1=0.0099 | 2=0.0002 | 3=0.4513 | 4=0.4719 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3324.3313 | _timers/batch_time=0.0106 | _timers/data_time=0.0083 | _timers/model_time=0.0022 | loss=0.4485
# 1/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.007, 2=0.004, 3=0.628, 4=0.000, _timers/_fps=46.299, loss=0.481]
# 1/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.75it/s, 0=1.000, 1=0.048, 2=0.000, 3=0.459, 4=1.000, _timers/_fps=3390.707, loss=0.344]
# [2019-08-11 01:30:03,982]
# 1/50 * Epoch 1 (train): 0=1.0000 | 1=0.0165 | 2=0.0005 | 3=0.4789 | 4=0.3496 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.8498 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.4717
# 1/50 * Epoch 1 (valid): 0=1.0000 | 1=0.0359 | 2=0.0003 | 3=0.4977 | 4=0.5105 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3247.1961 | _timers/batch_time=0.0121 | _timers/data_time=0.0099 | _timers/model_time=0.0022 | loss=0.4655
# 2/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.185, 2=0.000, 3=0.378, 4=0.586, _timers/_fps=45.000, loss=0.423]
# 2/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.63it/s, 0=1.000, 1=0.243, 2=0.000, 3=0.503, 4=1.000, _timers/_fps=3158.510, loss=0.280]
# [2019-08-11 01:33:49,532]
# 2/50 * Epoch 2 (train): 0=1.0000 | 1=0.0526 | 2=0.0005 | 3=0.5001 | 4=0.3789 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.8562 | _timers/batch_time=0.3490 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.4606
# 2/50 * Epoch 2 (valid): 0=1.0000 | 1=0.1175 | 2=0.0003 | 3=0.5341 | 4=0.5454 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3232.8251 | _timers/batch_time=0.0114 | _timers/data_time=0.0092 | _timers/model_time=0.0022 | loss=0.4109
# 3/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.428, 2=0.000, 3=0.255, 4=0.627, _timers/_fps=45.807, loss=0.392]
# 3/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.66it/s, 0=1.000, 1=0.426, 2=0.000, 3=0.350, 4=1.000, _timers/_fps=3639.704, loss=0.245]
# [2019-08-11 01:37:35,046]
# 3/50 * Epoch 3 (train): 0=1.0000 | 1=0.1805 | 2=0.0006 | 3=0.4984 | 4=0.4047 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.8798 | _timers/batch_time=0.3488 | _timers/data_time=0.3461 | _timers/model_time=0.0027 | loss=0.4405
# 3/50 * Epoch 3 (valid): 0=1.0000 | 1=0.2890 | 2=0.0003 | 3=0.4503 | 4=0.4586 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3216.6681 | _timers/batch_time=0.0115 | _timers/data_time=0.0092 | _timers/model_time=0.0022 | loss=0.3604
# 4/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.420, 2=0.000, 3=0.542, 4=0.000, _timers/_fps=45.615, loss=0.243]
# 4/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.78it/s, 0=1.000, 1=0.470, 2=0.000, 3=0.362, 4=1.000, _timers/_fps=3443.776, loss=0.240]
# [2019-08-11 01:41:20,296]
# 4/50 * Epoch 4 (train): 0=1.0000 | 1=0.2496 | 2=0.0006 | 3=0.5036 | 4=0.4119 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.9563 | _timers/batch_time=0.3483 | _timers/data_time=0.3455 | _timers/model_time=0.0027 | loss=0.4278
# 4/50 * Epoch 4 (valid): 0=1.0000 | 1=0.2644 | 2=0.0003 | 3=0.4686 | 4=0.5823 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3285.4245 | _timers/batch_time=0.0125 | _timers/data_time=0.0102 | _timers/model_time=0.0022 | loss=0.3769
# 5/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.423, 2=0.001, 3=0.636, 4=0.238, _timers/_fps=46.441, loss=0.535]
# 5/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.64it/s, 0=1.000, 1=0.464, 2=0.000, 3=0.375, 4=1.000, _timers/_fps=3528.702, loss=0.235]
# [2019-08-11 01:45:05,850]
# 5/50 * Epoch 5 (train): 0=1.0000 | 1=0.2644 | 2=0.0006 | 3=0.5096 | 4=0.4384 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.9073 | _timers/batch_time=0.3487 | _timers/data_time=0.3460 | _timers/model_time=0.0027 | loss=0.4119
# 5/50 * Epoch 5 (valid): 0=1.0000 | 1=0.3222 | 2=0.0004 | 3=0.4310 | 4=0.4105 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3373.4685 | _timers/batch_time=0.0123 | _timers/data_time=0.0101 | _timers/model_time=0.0022 | loss=0.3704
# 6/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.136, 2=0.005, 3=0.511, 4=0.655, _timers/_fps=45.742, loss=0.584]
# 6/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.65it/s, 0=1.000, 1=0.505, 2=0.000, 3=0.454, 4=1.000, _timers/_fps=3550.921, loss=0.209]
# [2019-08-11 01:48:51,120]
# 6/50 * Epoch 6 (train): 0=1.0000 | 1=0.3040 | 2=0.0006 | 3=0.5131 | 4=0.4387 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.9220 | _timers/batch_time=0.3485 | _timers/data_time=0.3458 | _timers/model_time=0.0027 | loss=0.3977
# 6/50 * Epoch 6 (valid): 0=1.0000 | 1=0.3536 | 2=0.0003 | 3=0.5040 | 4=0.5138 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3235.7034 | _timers/batch_time=0.0109 | _timers/data_time=0.0087 | _timers/model_time=0.0022 | loss=0.3416
# 7/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.199, 2=0.001, 3=0.376, 4=0.603, _timers/_fps=45.916, loss=0.556]
# 7/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.67it/s, 0=1.000, 1=0.425, 2=0.000, 3=0.483, 4=1.000, _timers/_fps=3676.594, loss=0.235]
# Epoch     7: reducing learning rate of group 0 to 2.0000e-04.
# [2019-08-11 01:52:36,497]
# 7/50 * Epoch 7 (train): 0=1.0000 | 1=0.3123 | 2=0.0006 | 3=0.5193 | 4=0.4292 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=45.9059 | _timers/batch_time=0.3486 | _timers/data_time=0.3459 | _timers/model_time=0.0027 | loss=0.3916
# 7/50 * Epoch 7 (valid): 0=1.0000 | 1=0.3488 | 2=0.0004 | 3=0.5061 | 4=0.5834 | _base/lr=0.0010 | _base/momentum=0.9000 | _timers/_fps=3351.6102 | _timers/batch_time=0.0122 | _timers/data_time=0.0100 | _timers/model_time=0.0022 | loss=0.3435
# 8/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.000, 2=0.001, 3=0.415, 4=0.462, _timers/_fps=45.864, loss=0.388]
# 8/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.60it/s, 0=1.000, 1=0.622, 2=0.000, 3=0.464, 4=1.000, _timers/_fps=3509.694, loss=0.195]
# [2019-08-11 01:56:22,086]
# 8/50 * Epoch 8 (train): 0=1.0000 | 1=0.3587 | 2=0.0006 | 3=0.5299 | 4=0.4836 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8855 | _timers/batch_time=0.3487 | _timers/data_time=0.3460 | _timers/model_time=0.0027 | loss=0.3694
# 8/50 * Epoch 8 (valid): 0=1.0000 | 1=0.4220 | 2=0.0004 | 3=0.5215 | 4=0.5280 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3347.1877 | _timers/batch_time=0.0120 | _timers/data_time=0.0098 | _timers/model_time=0.0021 | loss=0.3104
# 9/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.641, 2=0.000, 3=0.632, 4=0.331, _timers/_fps=46.158, loss=0.296]
# 9/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.72it/s, 0=1.000, 1=0.630, 2=0.000, 3=0.530, 4=1.000, _timers/_fps=3561.664, loss=0.178]
# [2019-08-11 02:00:07,416]
# 9/50 * Epoch 9 (train): 0=1.0000 | 1=0.3884 | 2=0.0006 | 3=0.5341 | 4=0.4767 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8925 | _timers/batch_time=0.3487 | _timers/data_time=0.3460 | _timers/model_time=0.0027 | loss=0.3603
# 9/50 * Epoch 9 (valid): 0=1.0000 | 1=0.5141 | 2=0.0003 | 3=0.5379 | 4=0.5711 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3283.2357 | _timers/batch_time=0.0113 | _timers/data_time=0.0091 | _timers/model_time=0.0022 | loss=0.3080
# 10/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.362, 2=0.000, 3=0.557, 4=0.537, _timers/_fps=46.051, loss=0.253]
# 10/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.66it/s, 0=1.000, 1=0.627, 2=0.000, 3=0.548, 4=1.000, _timers/_fps=3677.601, loss=0.150]
# [2019-08-11 02:03:52,927]
# 10/50 * Epoch 10 (train): 0=1.0000 | 1=0.3946 | 2=0.0006 | 3=0.5351 | 4=0.4663 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8649 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3552
# 10/50 * Epoch 10 (valid): 0=1.0000 | 1=0.4991 | 2=0.0003 | 3=0.5407 | 4=0.5800 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3415.0071 | _timers/batch_time=0.0119 | _timers/data_time=0.0098 | _timers/model_time=0.0021 | loss=0.3062
# 11/50 * Epoch (train): 100% 417/417 [03:36<00:00,  1.98it/s, 0=1.000, 1=0.455, 2=0.000, 3=0.390, 4=0.581, _timers/_fps=46.417, loss=0.290]
# 11/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.72it/s, 0=1.000, 1=0.610, 2=0.000, 3=0.448, 4=1.000, _timers/_fps=3653.376, loss=0.158]
# [2019-08-11 02:07:37,310]
# 11/50 * Epoch 11 (train): 0=1.0000 | 1=0.3955 | 2=0.0006 | 3=0.5377 | 4=0.4743 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8645 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3495
# 11/50 * Epoch 11 (valid): 0=1.0000 | 1=0.4498 | 2=0.0003 | 3=0.5132 | 4=0.5926 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3290.8141 | _timers/batch_time=0.0116 | _timers/data_time=0.0094 | _timers/model_time=0.0022 | loss=0.3020
# 12/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.526, 2=0.001, 3=0.568, 4=0.570, _timers/_fps=45.405, loss=0.377]
# 12/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.68it/s, 0=1.000, 1=0.592, 2=0.000, 3=0.505, 4=1.000, _timers/_fps=3683.051, loss=0.149]
# [2019-08-11 02:11:22,854]
# 12/50 * Epoch 12 (train): 0=1.0000 | 1=0.4050 | 2=0.0006 | 3=0.5396 | 4=0.4912 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8598 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3504
# 12/50 * Epoch 12 (valid): 0=1.0000 | 1=0.4603 | 2=0.0004 | 3=0.5212 | 4=0.6479 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3423.0649 | _timers/batch_time=0.0123 | _timers/data_time=0.0101 | _timers/model_time=0.0021 | loss=0.3011
# 13/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.530, 2=0.001, 3=0.580, 4=0.666, _timers/_fps=45.148, loss=0.408]
# 13/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.65it/s, 0=1.000, 1=0.563, 2=0.000, 3=0.555, 4=1.000, _timers/_fps=3431.274, loss=0.154]
# Epoch    13: reducing learning rate of group 0 to 4.0000e-05.
# [2019-08-11 02:15:08,343]
# 13/50 * Epoch 13 (train): 0=1.0000 | 1=0.4083 | 2=0.0006 | 3=0.5419 | 4=0.4921 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=45.8413 | _timers/batch_time=0.3491 | _timers/data_time=0.3464 | _timers/model_time=0.0027 | loss=0.3472
# 13/50 * Epoch 13 (valid): 0=1.0000 | 1=0.3916 | 2=0.0004 | 3=0.5654 | 4=0.5664 | _base/lr=0.0002 | _base/momentum=0.9000 | _timers/_fps=3304.8103 | _timers/batch_time=0.0124 | _timers/data_time=0.0102 | _timers/model_time=0.0022 | loss=0.3023
# 14/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.000, 2=0.001, 3=0.593, 4=0.000, _timers/_fps=46.166, loss=0.290]
# 14/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.61it/s, 0=1.000, 1=0.589, 2=0.000, 3=0.535, 4=1.000, _timers/_fps=3637.337, loss=0.140]
# [2019-08-11 02:18:53,978]
# 14/50 * Epoch 14 (train): 0=1.0000 | 1=0.4283 | 2=0.0006 | 3=0.5436 | 4=0.4826 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8157 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0026 | loss=0.3431
# 14/50 * Epoch 14 (valid): 0=1.0000 | 1=0.4618 | 2=0.0004 | 3=0.5433 | 4=0.5361 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3222.1529 | _timers/batch_time=0.0122 | _timers/data_time=0.0100 | _timers/model_time=0.0022 | loss=0.2904
# 15/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.000, 2=0.000, 3=0.609, 4=0.523, _timers/_fps=46.302, loss=0.162]
# 15/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.64it/s, 0=1.000, 1=0.591, 2=0.000, 3=0.492, 4=1.000, _timers/_fps=3443.599, loss=0.148]
# [2019-08-11 02:22:39,459]
# 15/50 * Epoch 15 (train): 0=1.0000 | 1=0.4177 | 2=0.0006 | 3=0.5458 | 4=0.5193 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8267 | _timers/batch_time=0.3492 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3291
# 15/50 * Epoch 15 (valid): 0=1.0000 | 1=0.4668 | 2=0.0004 | 3=0.5330 | 4=0.6059 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3185.0449 | _timers/batch_time=0.0118 | _timers/data_time=0.0097 | _timers/model_time=0.0021 | loss=0.2911
# 16/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.442, 2=0.000, 3=0.617, 4=0.000, _timers/_fps=45.196, loss=0.127]
# 16/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.61it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.546, 4=1.000, _timers/_fps=3437.602, loss=0.136]
# [2019-08-11 02:26:25,004]
# 16/50 * Epoch 16 (train): 0=1.0000 | 1=0.4434 | 2=0.0006 | 3=0.5500 | 4=0.5143 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8505 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3357
# 16/50 * Epoch 16 (valid): 0=1.0000 | 1=0.4679 | 2=0.0004 | 3=0.5549 | 4=0.5591 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3247.3954 | _timers/batch_time=0.0115 | _timers/data_time=0.0093 | _timers/model_time=0.0022 | loss=0.2925
# 17/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.605, 2=0.003, 3=0.557, 4=0.540, _timers/_fps=45.608, loss=0.451]
# 17/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.68it/s, 0=1.000, 1=0.594, 2=0.000, 3=0.537, 4=1.000, _timers/_fps=3453.168, loss=0.141]
# [2019-08-11 02:30:10,453]
# 17/50 * Epoch 17 (train): 0=1.0000 | 1=0.4321 | 2=0.0006 | 3=0.5439 | 4=0.4940 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8173 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3328
# 17/50 * Epoch 17 (valid): 0=1.0000 | 1=0.4747 | 2=0.0004 | 3=0.5547 | 4=0.5474 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3346.8984 | _timers/batch_time=0.0120 | _timers/data_time=0.0098 | _timers/model_time=0.0022 | loss=0.2913
# 18/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.000, 3=0.533, 4=0.551, _timers/_fps=45.447, loss=0.161]
# 18/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.76it/s, 0=1.000, 1=0.591, 2=0.000, 3=0.538, 4=1.000, _timers/_fps=3534.650, loss=0.137]
# [2019-08-11 02:33:56,058]
# 18/50 * Epoch 18 (train): 0=1.0000 | 1=0.4255 | 2=0.0006 | 3=0.5453 | 4=0.5116 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8193 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3346
# 18/50 * Epoch 18 (valid): 0=1.0000 | 1=0.4628 | 2=0.0004 | 3=0.5474 | 4=0.5542 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3270.0844 | _timers/batch_time=0.0119 | _timers/data_time=0.0098 | _timers/model_time=0.0021 | loss=0.2878
# 19/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.569, 2=0.000, 3=0.558, 4=0.000, _timers/_fps=45.518, loss=0.131]
# 19/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.74it/s, 0=1.000, 1=0.582, 2=0.000, 3=0.530, 4=1.000, _timers/_fps=3441.304, loss=0.144]
# Epoch    19: reducing learning rate of group 0 to 8.0000e-06.
# [2019-08-11 02:37:41,536]
# 19/50 * Epoch 19 (train): 0=1.0000 | 1=0.4356 | 2=0.0006 | 3=0.5497 | 4=0.5097 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=45.8327 | _timers/batch_time=0.3491 | _timers/data_time=0.3464 | _timers/model_time=0.0027 | loss=0.3324
# 19/50 * Epoch 19 (valid): 0=1.0000 | 1=0.4668 | 2=0.0004 | 3=0.5503 | 4=0.5535 | _base/lr=4.000000E-05 | _base/momentum=0.9000 | _timers/_fps=3267.4978 | _timers/batch_time=0.0123 | _timers/data_time=0.0100 | _timers/model_time=0.0023 | loss=0.2889
# 20/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.000, 2=0.000, 3=0.402, 4=0.639, _timers/_fps=45.324, loss=0.215]
# 20/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.74it/s, 0=1.000, 1=0.587, 2=0.000, 3=0.544, 4=1.000, _timers/_fps=3540.617, loss=0.141]
# [2019-08-11 02:41:27,144]
# 20/50 * Epoch 20 (train): 0=1.0000 | 1=0.4242 | 2=0.0006 | 3=0.5459 | 4=0.5172 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8172 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3250
# 20/50 * Epoch 20 (valid): 0=1.0000 | 1=0.4605 | 2=0.0004 | 3=0.5536 | 4=0.5820 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3168.3833 | _timers/batch_time=0.0115 | _timers/data_time=0.0093 | _timers/model_time=0.0021 | loss=0.2890
# 21/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.639, 2=0.004, 3=0.535, 4=1.000, _timers/_fps=46.817, loss=0.378]
# 21/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.61it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.542, 4=1.000, _timers/_fps=3521.111, loss=0.142]
# [2019-08-11 02:45:12,684]
# 21/50 * Epoch 21 (train): 0=1.0000 | 1=0.4397 | 2=0.0006 | 3=0.5463 | 4=0.5052 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8636 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3393
# 21/50 * Epoch 21 (valid): 0=1.0000 | 1=0.4736 | 2=0.0004 | 3=0.5570 | 4=0.5499 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3216.4750 | _timers/batch_time=0.0114 | _timers/data_time=0.0091 | _timers/model_time=0.0022 | loss=0.2893
# 22/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.438, 2=0.000, 3=0.402, 4=0.000, _timers/_fps=46.569, loss=0.297]
# 22/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.71it/s, 0=1.000, 1=0.598, 2=0.000, 3=0.533, 4=1.000, _timers/_fps=3540.617, loss=0.139]
# [2019-08-11 02:48:58,149]
# 22/50 * Epoch 22 (train): 0=1.0000 | 1=0.4419 | 2=0.0006 | 3=0.5488 | 4=0.4976 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8583 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3303
# 22/50 * Epoch 22 (valid): 0=1.0000 | 1=0.4664 | 2=0.0004 | 3=0.5460 | 4=0.5520 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3233.1837 | _timers/batch_time=0.0121 | _timers/data_time=0.0100 | _timers/model_time=0.0022 | loss=0.2875
# 23/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.579, 2=0.000, 3=0.469, 4=0.569, _timers/_fps=46.572, loss=0.266]
# 23/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.64it/s, 0=1.000, 1=0.613, 2=0.000, 3=0.534, 4=1.000, _timers/_fps=3417.296, loss=0.139]
# [2019-08-11 02:52:43,594]
# 23/50 * Epoch 23 (train): 0=1.0000 | 1=0.4348 | 2=0.0006 | 3=0.5534 | 4=0.5189 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8738 | _timers/batch_time=0.3489 | _timers/data_time=0.3461 | _timers/model_time=0.0027 | loss=0.3253
# 23/50 * Epoch 23 (valid): 0=1.0000 | 1=0.4808 | 2=0.0004 | 3=0.5462 | 4=0.5883 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3153.6588 | _timers/batch_time=0.0110 | _timers/data_time=0.0088 | _timers/model_time=0.0022 | loss=0.2905
# 24/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.584, 2=0.000, 3=0.500, 4=0.639, _timers/_fps=46.247, loss=0.410]
# 24/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.74it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.539, 4=1.000, _timers/_fps=3644.052, loss=0.139]
# [2019-08-11 02:56:29,241]
# 24/50 * Epoch 24 (train): 0=1.0000 | 1=0.4425 | 2=0.0006 | 3=0.5493 | 4=0.5037 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8531 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3257
# 24/50 * Epoch 24 (valid): 0=1.0000 | 1=0.4723 | 2=0.0004 | 3=0.5513 | 4=0.5586 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3279.5699 | _timers/batch_time=0.0124 | _timers/data_time=0.0103 | _timers/model_time=0.0022 | loss=0.2885
# 25/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.596, 2=0.000, 3=0.516, 4=0.572, _timers/_fps=45.629, loss=0.180]
# 25/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.70it/s, 0=1.000, 1=0.596, 2=0.000, 3=0.550, 4=1.000, _timers/_fps=3656.960, loss=0.142]
# Epoch    25: reducing learning rate of group 0 to 1.6000e-06.
# [2019-08-11 03:00:14,821]
# 25/50 * Epoch 25 (train): 0=1.0000 | 1=0.4436 | 2=0.0006 | 3=0.5483 | 4=0.5049 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8184 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3317
# 25/50 * Epoch 25 (valid): 0=1.0000 | 1=0.4702 | 2=0.0004 | 3=0.5593 | 4=0.5605 | _base/lr=8.000000E-06 | _base/momentum=0.9000 | _timers/_fps=3346.3693 | _timers/batch_time=0.0122 | _timers/data_time=0.0100 | _timers/model_time=0.0022 | loss=0.2897
# 26/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.577, 2=0.000, 3=0.521, 4=0.636, _timers/_fps=46.287, loss=0.230]
# 26/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.71it/s, 0=1.000, 1=0.605, 2=0.000, 3=0.536, 4=1.000, _timers/_fps=3115.980, loss=0.142]
# [2019-08-11 03:04:00,397]
# 26/50 * Epoch 26 (train): 0=1.0000 | 1=0.4455 | 2=0.0006 | 3=0.5483 | 4=0.5009 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8695 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3326
# 26/50 * Epoch 26 (valid): 0=1.0000 | 1=0.4785 | 2=0.0004 | 3=0.5517 | 4=0.5582 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3284.5658 | _timers/batch_time=0.0117 | _timers/data_time=0.0095 | _timers/model_time=0.0022 | loss=0.2888
# 27/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.454, 2=0.006, 3=0.343, 4=0.588, _timers/_fps=45.348, loss=0.488]
# 27/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.67it/s, 0=1.000, 1=0.598, 2=0.000, 3=0.539, 4=1.000, _timers/_fps=3514.657, loss=0.141]
# [2019-08-11 03:07:45,569]
# 27/50 * Epoch 27 (train): 0=1.0000 | 1=0.4511 | 2=0.0006 | 3=0.5487 | 4=0.5094 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8868 | _timers/batch_time=0.3488 | _timers/data_time=0.3461 | _timers/model_time=0.0027 | loss=0.3273
# 27/50 * Epoch 27 (valid): 0=1.0000 | 1=0.4688 | 2=0.0004 | 3=0.5507 | 4=0.5530 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3277.9013 | _timers/batch_time=0.0115 | _timers/data_time=0.0092 | _timers/model_time=0.0022 | loss=0.2879
# 28/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.492, 2=0.000, 3=0.258, 4=0.606, _timers/_fps=45.513, loss=0.316]
# 28/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.79it/s, 0=1.000, 1=0.607, 2=0.000, 3=0.527, 4=1.000, _timers/_fps=3633.595, loss=0.141]
# [2019-08-11 03:11:31,069]
# 28/50 * Epoch 28 (train): 0=1.0000 | 1=0.4489 | 2=0.0006 | 3=0.5495 | 4=0.4894 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8081 | _timers/batch_time=0.3494 | _timers/data_time=0.3467 | _timers/model_time=0.0027 | loss=0.3316
# 28/50 * Epoch 28 (valid): 0=1.0000 | 1=0.4823 | 2=0.0004 | 3=0.5439 | 4=0.5596 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3212.8108 | _timers/batch_time=0.0119 | _timers/data_time=0.0097 | _timers/model_time=0.0022 | loss=0.2895
# 29/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.580, 2=0.000, 3=0.586, 4=0.658, _timers/_fps=46.396, loss=0.234]
# 29/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.67it/s, 0=1.000, 1=0.604, 2=0.000, 3=0.538, 4=1.000, _timers/_fps=3347.409, loss=0.142]
# [2019-08-11 03:15:16,550]
# 29/50 * Epoch 29 (train): 0=1.0000 | 1=0.4411 | 2=0.0006 | 3=0.5479 | 4=0.5088 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8027 | _timers/batch_time=0.3494 | _timers/data_time=0.3467 | _timers/model_time=0.0027 | loss=0.3305
# 29/50 * Epoch 29 (valid): 0=1.0000 | 1=0.4736 | 2=0.0004 | 3=0.5524 | 4=0.5882 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3234.6185 | _timers/batch_time=0.0124 | _timers/data_time=0.0101 | _timers/model_time=0.0023 | loss=0.2911
# 30/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.426, 2=0.000, 3=0.523, 4=0.619, _timers/_fps=45.609, loss=0.242]
# 30/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.74it/s, 0=1.000, 1=0.589, 2=0.000, 3=0.517, 4=1.000, _timers/_fps=3552.425, loss=0.144]
# [2019-08-11 03:19:02,125]
# 30/50 * Epoch 30 (train): 0=1.0000 | 1=0.4411 | 2=0.0006 | 3=0.5503 | 4=0.5053 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8025 | _timers/batch_time=0.3494 | _timers/data_time=0.3467 | _timers/model_time=0.0027 | loss=0.3260
# 30/50 * Epoch 30 (valid): 0=1.0000 | 1=0.4670 | 2=0.0004 | 3=0.5383 | 4=0.5585 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3227.3167 | _timers/batch_time=0.0117 | _timers/data_time=0.0095 | _timers/model_time=0.0022 | loss=0.2876
# 31/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.003, 3=0.578, 4=0.660, _timers/_fps=46.196, loss=0.492]
# 31/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.62it/s, 0=1.000, 1=0.598, 2=0.000, 3=0.536, 4=1.000, _timers/_fps=3510.245, loss=0.141]
# Epoch    31: reducing learning rate of group 0 to 3.2000e-07.
# [2019-08-11 03:22:47,531]
# 31/50 * Epoch 31 (train): 0=1.0000 | 1=0.4441 | 2=0.0006 | 3=0.5483 | 4=0.5062 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=45.8671 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3240
# 31/50 * Epoch 31 (valid): 0=1.0000 | 1=0.4702 | 2=0.0004 | 3=0.5500 | 4=0.5549 | _base/lr=1.600000E-06 | _base/momentum=0.9000 | _timers/_fps=3365.5059 | _timers/batch_time=0.0116 | _timers/data_time=0.0094 | _timers/model_time=0.0022 | loss=0.2876
# 32/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.284, 2=0.000, 3=0.613, 4=0.000, _timers/_fps=45.634, loss=0.244]
# 32/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.63it/s, 0=1.000, 1=0.599, 2=0.000, 3=0.539, 4=1.000, _timers/_fps=3674.581, loss=0.139]
# [2019-08-11 03:26:33,080]
# 32/50 * Epoch 32 (train): 0=1.0000 | 1=0.4473 | 2=0.0006 | 3=0.5476 | 4=0.5100 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8635 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3303
# 32/50 * Epoch 32 (valid): 0=1.0000 | 1=0.4707 | 2=0.0004 | 3=0.5506 | 4=0.5550 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3293.4620 | _timers/batch_time=0.0117 | _timers/data_time=0.0095 | _timers/model_time=0.0022 | loss=0.2876
# 33/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.458, 2=0.000, 3=0.558, 4=1.000, _timers/_fps=45.669, loss=0.180]
# 33/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.76it/s, 0=1.000, 1=0.599, 2=0.000, 3=0.545, 4=1.000, _timers/_fps=3635.957, loss=0.139]
# [2019-08-11 03:30:18,568]
# 33/50 * Epoch 33 (train): 0=1.0000 | 1=0.4463 | 2=0.0006 | 3=0.5467 | 4=0.5116 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8587 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3313
# 33/50 * Epoch 33 (valid): 0=1.0000 | 1=0.4741 | 2=0.0004 | 3=0.5557 | 4=0.5506 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3262.4322 | _timers/batch_time=0.0113 | _timers/data_time=0.0091 | _timers/model_time=0.0022 | loss=0.2879
# 34/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.486, 2=0.001, 3=0.545, 4=1.000, _timers/_fps=45.622, loss=0.374]
# 34/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.63it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.528, 4=1.000, _timers/_fps=3632.022, loss=0.140]
# [2019-08-11 03:34:04,132]
# 34/50 * Epoch 34 (train): 0=1.0000 | 1=0.4428 | 2=0.0006 | 3=0.5473 | 4=0.5030 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8225 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3310
# 34/50 * Epoch 34 (valid): 0=1.0000 | 1=0.4754 | 2=0.0004 | 3=0.5438 | 4=0.5557 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3358.9144 | _timers/batch_time=0.0117 | _timers/data_time=0.0096 | _timers/model_time=0.0022 | loss=0.2877
# 35/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.618, 2=0.003, 3=0.504, 4=1.000, _timers/_fps=45.377, loss=0.398]
# 35/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.75it/s, 0=1.000, 1=0.601, 2=0.000, 3=0.533, 4=1.000, _timers/_fps=3541.926, loss=0.140]
# [2019-08-11 03:37:49,844]
# 35/50 * Epoch 35 (train): 0=1.0000 | 1=0.4418 | 2=0.0006 | 3=0.5503 | 4=0.5054 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8221 | _timers/batch_time=0.3493 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3285
# 35/50 * Epoch 35 (valid): 0=1.0000 | 1=0.4753 | 2=0.0004 | 3=0.5451 | 4=0.5559 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3368.1409 | _timers/batch_time=0.0124 | _timers/data_time=0.0102 | _timers/model_time=0.0021 | loss=0.2882
# 36/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.170, 2=0.001, 3=0.331, 4=0.000, _timers/_fps=45.681, loss=0.526]
# 36/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.64it/s, 0=1.000, 1=0.586, 2=0.000, 3=0.526, 4=1.000, _timers/_fps=3419.386, loss=0.142]
# [2019-08-11 03:41:35,385]
# 36/50 * Epoch 36 (train): 0=1.0000 | 1=0.4349 | 2=0.0006 | 3=0.5491 | 4=0.5107 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8485 | _timers/batch_time=0.3490 | _timers/data_time=0.3463 | _timers/model_time=0.0027 | loss=0.3259
# 36/50 * Epoch 36 (valid): 0=1.0000 | 1=0.4639 | 2=0.0004 | 3=0.5426 | 4=0.5563 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3186.4148 | _timers/batch_time=0.0122 | _timers/data_time=0.0099 | _timers/model_time=0.0023 | loss=0.2872
# 37/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.99it/s, 0=1.000, 1=0.412, 2=0.000, 3=0.529, 4=0.617, _timers/_fps=46.756, loss=0.291]
# 37/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.80it/s, 0=1.000, 1=0.605, 2=0.000, 3=0.531, 4=1.000, _timers/_fps=3557.510, loss=0.140]
# Epoch    37: reducing learning rate of group 0 to 6.4000e-08.
# [2019-08-11 03:45:20,986]
# 37/50 * Epoch 37 (train): 0=1.0000 | 1=0.4429 | 2=0.0006 | 3=0.5516 | 4=0.5080 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=45.8337 | _timers/batch_time=0.3492 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3289
# 37/50 * Epoch 37 (valid): 0=1.0000 | 1=0.4800 | 2=0.0004 | 3=0.5453 | 4=0.5524 | _base/lr=3.200000E-07 | _base/momentum=0.9000 | _timers/_fps=3266.2627 | _timers/batch_time=0.0114 | _timers/data_time=0.0093 | _timers/model_time=0.0021 | loss=0.2875
# 38/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.351, 2=0.000, 3=0.517, 4=0.630, _timers/_fps=45.952, loss=0.292]
# 38/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.74it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.522, 4=1.000, _timers/_fps=3438.306, loss=0.141]
# [2019-08-11 03:49:06,788]
# 38/50 * Epoch 38 (train): 0=1.0000 | 1=0.4379 | 2=0.0006 | 3=0.5488 | 4=0.5167 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.7986 | _timers/batch_time=0.3494 | _timers/data_time=0.3467 | _timers/model_time=0.0027 | loss=0.3314
# 38/50 * Epoch 38 (valid): 0=1.0000 | 1=0.4721 | 2=0.0004 | 3=0.5397 | 4=0.5884 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3254.1022 | _timers/batch_time=0.0125 | _timers/data_time=0.0103 | _timers/model_time=0.0022 | loss=0.2893
# 39/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.000, 3=0.627, 4=0.573, _timers/_fps=45.438, loss=0.138]
# 39/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.80it/s, 0=1.000, 1=0.601, 2=0.000, 3=0.545, 4=1.000, _timers/_fps=3493.798, loss=0.139]
# [2019-08-11 03:52:52,215]
# 39/50 * Epoch 39 (train): 0=1.0000 | 1=0.4437 | 2=0.0006 | 3=0.5500 | 4=0.5123 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8330 | _timers/batch_time=0.3492 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3279
# 39/50 * Epoch 39 (valid): 0=1.0000 | 1=0.4686 | 2=0.0004 | 3=0.5529 | 4=0.5623 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3269.6253 | _timers/batch_time=0.0120 | _timers/data_time=0.0098 | _timers/model_time=0.0022 | loss=0.2889
# 40/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.347, 2=0.000, 3=0.532, 4=0.000, _timers/_fps=45.434, loss=0.211]
# 40/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.62it/s, 0=1.000, 1=0.601, 2=0.000, 3=0.536, 4=1.000, _timers/_fps=3684.264, loss=0.141]
# [2019-08-11 03:56:37,913]
# 40/50 * Epoch 40 (train): 0=1.0000 | 1=0.4429 | 2=0.0006 | 3=0.5495 | 4=0.5043 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8177 | _timers/batch_time=0.3493 | _timers/data_time=0.3466 | _timers/model_time=0.0027 | loss=0.3251
# 40/50 * Epoch 40 (valid): 0=1.0000 | 1=0.4730 | 2=0.0004 | 3=0.5490 | 4=0.5589 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3278.4877 | _timers/batch_time=0.0115 | _timers/data_time=0.0093 | _timers/model_time=0.0021 | loss=0.2886
# 41/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.617, 2=0.000, 3=0.545, 4=0.665, _timers/_fps=45.976, loss=0.174]
# 41/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.70it/s, 0=1.000, 1=0.611, 2=0.000, 3=0.550, 4=1.000, _timers/_fps=3422.874, loss=0.140]
# [2019-08-11 04:00:23,418]
# 41/50 * Epoch 41 (train): 0=1.0000 | 1=0.4492 | 2=0.0006 | 3=0.5479 | 4=0.5325 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8343 | _timers/batch_time=0.3491 | _timers/data_time=0.3464 | _timers/model_time=0.0027 | loss=0.3356
# 41/50 * Epoch 41 (valid): 0=1.0000 | 1=0.5109 | 2=0.0004 | 3=0.5575 | 4=0.5567 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3204.2164 | _timers/batch_time=0.0128 | _timers/data_time=0.0106 | _timers/model_time=0.0022 | loss=0.2904
# 42/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.002, 3=0.525, 4=0.606, _timers/_fps=45.561, loss=0.337]
# 42/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.70it/s, 0=1.000, 1=0.602, 2=0.000, 3=0.524, 4=1.000, _timers/_fps=3564.691, loss=0.141]
# [2019-08-11 04:04:08,863]
# 42/50 * Epoch 42 (train): 0=1.0000 | 1=0.4335 | 2=0.0006 | 3=0.5498 | 4=0.5177 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8773 | _timers/batch_time=0.3488 | _timers/data_time=0.3461 | _timers/model_time=0.0027 | loss=0.3221
# 42/50 * Epoch 42 (valid): 0=1.0000 | 1=0.4772 | 2=0.0004 | 3=0.5433 | 4=0.5598 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3128.5075 | _timers/batch_time=0.0118 | _timers/data_time=0.0096 | _timers/model_time=0.0021 | loss=0.2888
# 43/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.002, 3=0.553, 4=0.656, _timers/_fps=45.536, loss=0.302]
# 43/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.79it/s, 0=1.000, 1=0.603, 2=0.000, 3=0.544, 4=1.000, _timers/_fps=3475.703, loss=0.141]
# Epoch    43: reducing learning rate of group 0 to 1.2800e-08.
# [2019-08-11 04:07:54,393]
# 43/50 * Epoch 43 (train): 0=1.0000 | 1=0.4392 | 2=0.0006 | 3=0.5479 | 4=0.5134 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8308 | _timers/batch_time=0.3492 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3255
# 43/50 * Epoch 43 (valid): 0=1.0000 | 1=0.4747 | 2=0.0004 | 3=0.5546 | 4=0.5575 | _base/lr=6.400000E-08 | _base/momentum=0.9000 | _timers/_fps=3296.3570 | _timers/batch_time=0.0121 | _timers/data_time=0.0099 | _timers/model_time=0.0022 | loss=0.2887
# 44/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.444, 2=0.000, 3=0.625, 4=1.000, _timers/_fps=45.302, loss=0.214]
# 44/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.65it/s, 0=1.000, 1=0.588, 2=0.000, 3=0.551, 4=1.000, _timers/_fps=3545.856, loss=0.140]
# [2019-08-11 04:11:40,010]
# 44/50 * Epoch 44 (train): 0=1.0000 | 1=0.4383 | 2=0.0006 | 3=0.5494 | 4=0.5047 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8728 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3172
# 44/50 * Epoch 44 (valid): 0=1.0000 | 1=0.4654 | 2=0.0004 | 3=0.5596 | 4=0.5527 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3263.0781 | _timers/batch_time=0.0110 | _timers/data_time=0.0089 | _timers/model_time=0.0021 | loss=0.2875
# 45/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.000, 2=0.001, 3=0.502, 4=0.603, _timers/_fps=45.588, loss=0.370]
# 45/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.77it/s, 0=1.000, 1=0.601, 2=0.000, 3=0.506, 4=1.000, _timers/_fps=3680.828, loss=0.143]
# [2019-08-11 04:15:25,642]
# 45/50 * Epoch 45 (train): 0=1.0000 | 1=0.4387 | 2=0.0006 | 3=0.5487 | 4=0.5087 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8341 | _timers/batch_time=0.3492 | _timers/data_time=0.3465 | _timers/model_time=0.0027 | loss=0.3293
# 45/50 * Epoch 45 (valid): 0=1.0000 | 1=0.4729 | 2=0.0004 | 3=0.5336 | 4=0.5870 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3281.1592 | _timers/batch_time=0.0119 | _timers/data_time=0.0097 | _timers/model_time=0.0021 | loss=0.2893
# 46/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.98it/s, 0=1.000, 1=0.549, 2=0.000, 3=0.616, 4=0.554, _timers/_fps=46.479, loss=0.215]
# 46/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.71it/s, 0=1.000, 1=0.607, 2=0.000, 3=0.547, 4=1.000, _timers/_fps=3643.656, loss=0.139]
# [2019-08-11 04:19:11,052]
# 46/50 * Epoch 46 (train): 0=1.0000 | 1=0.4549 | 2=0.0006 | 3=0.5518 | 4=0.5195 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8882 | _timers/batch_time=0.3488 | _timers/data_time=0.3461 | _timers/model_time=0.0027 | loss=0.3298
# 46/50 * Epoch 46 (valid): 0=1.0000 | 1=0.4778 | 2=0.0004 | 3=0.5574 | 4=0.5612 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3231.2099 | _timers/batch_time=0.0121 | _timers/data_time=0.0098 | _timers/model_time=0.0023 | loss=0.2898
# 47/50 * Epoch (train): 100% 417/417 [03:37<00:00,  1.97it/s, 0=1.000, 1=0.575, 2=0.000, 3=0.596, 4=0.642, _timers/_fps=45.327, loss=0.205]
# 47/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.71it/s, 0=1.000, 1=0.599, 2=0.000, 3=0.560, 4=1.000, _timers/_fps=3487.080, loss=0.141]
# [2019-08-11 04:22:56,639]
# 47/50 * Epoch 47 (train): 0=1.0000 | 1=0.4458 | 2=0.0006 | 3=0.5492 | 4=0.5076 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8681 | _timers/batch_time=0.3489 | _timers/data_time=0.3462 | _timers/model_time=0.0027 | loss=0.3220
# 47/50 * Epoch 47 (valid): 0=1.0000 | 1=0.4665 | 2=0.0004 | 3=0.5673 | 4=0.5615 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3236.4266 | _timers/batch_time=0.0120 | _timers/data_time=0.0098 | _timers/model_time=0.0022 | loss=0.2914
# 48/50 * Epoch (train): 100% 417/417 [03:38<00:00,  1.97it/s, 0=1.000, 1=0.527, 2=0.000, 3=0.575, 4=0.639, _timers/_fps=45.206, loss=0.243]
# 48/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.81it/s, 0=1.000, 1=0.608, 2=0.000, 3=0.544, 4=1.000, _timers/_fps=3549.794, loss=0.140]
# [2019-08-11 04:26:43,135]
# 48/50 * Epoch 48 (train): 0=1.0000 | 1=0.4428 | 2=0.0006 | 3=0.5494 | 4=0.4906 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.8959 | _timers/batch_time=0.3487 | _timers/data_time=0.3460 | _timers/model_time=0.0027 | loss=0.3264
# 48/50 * Epoch 48 (valid): 0=1.0000 | 1=0.4836 | 2=0.0004 | 3=0.5545 | 4=0.5583 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3274.3965 | _timers/batch_time=0.0120 | _timers/data_time=0.0098 | _timers/model_time=0.0022 | loss=0.2896
# 49/50 * Epoch (train): 100% 417/417 [03:38<00:00,  1.98it/s, 0=1.000, 1=0.530, 2=0.000, 3=0.577, 4=0.000, _timers/_fps=46.627, loss=0.191]
# 49/50 * Epoch (valid): 100% 42/42 [00:07<00:00,  6.83it/s, 0=1.000, 1=0.590, 2=0.000, 3=0.540, 4=1.000, _timers/_fps=3449.618, loss=0.140]
# Epoch    49: reducing learning rate of group 0 to 2.5600e-09.
# [2019-08-11 04:30:29,505]
# 49/50 * Epoch 49 (train): 0=1.0000 | 1=0.4232 | 2=0.0006 | 3=0.5486 | 4=0.5057 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=45.9293 | _timers/batch_time=0.3484 | _timers/data_time=0.3457 | _timers/model_time=0.0027 | loss=0.3292
# 49/50 * Epoch 49 (valid): 0=1.0000 | 1=0.4683 | 2=0.0004 | 3=0.5497 | 4=0.5492 | _base/lr=1.280000E-08 | _base/momentum=0.9000 | _timers/_fps=3088.4571 | _timers/batch_time=0.0122 | _timers/data_time=0.0099 | _timers/model_time=0.0023 | loss=0.2868
# Top best models:
# logs/checkpoints//train.1.pth	0.4655
# logs/checkpoints//train.0.pth	0.4485
# logs/checkpoints//train.2.pth	0.4109
