# %%
import numpy as np
import matplotlib.pyplot as plt

from datasets import get_dataset
from utils import load_config

# %matplotlib inline

# %%
c = load_config('../configs/linknet_4chan.yml')
d = get_dataset(**c['validation'])

# %%
d[0][0].shape, d[0][1].shape
# Out:
# (torch.Size([3, 256, 1600]), torch.Size([4, 256, 1600]))

# %%
np.unique(d[0][1])
# Out:
# array([0., 1.], dtype=float32)

# %%
plt.figure(figsize=(15, 10))
plt.imshow(d[8][1].numpy()[2])

# %%
plt.figure(figsize=(15, 10))
plt.imshow(d[8][0].numpy()[0])
